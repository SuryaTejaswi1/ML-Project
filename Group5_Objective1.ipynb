# %% [markdown]
# ## Objective-1: User expertise - performed a multinomial classification to predict the expertise of  various participants in the study

# %% [markdown]
# - We have performed Decision Tree, Random Forest, Gradient Boosting, Light Gradient Boosting, XG Boosting classification on data before and after sampling with hyperparameter tuning.

# %% [markdown]
# # Before Resampling

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter

df = pd.read_csv('Grid_Anonymized.csv')

df = df.drop('Unnamed: 0', axis=1)

for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df[col].fillna(df[col].median(), inplace=True)
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

X = pd.get_dummies(df[['Gender', 'Age', 'Fixations_Count', 'First_Fixation_Duration', 
                        'Average_Fixations_Duration', 'Time_spent_F_Percentage', 
                        'Revisit_F_Revisits', 'Revisit_F_Visitors', 'Revisit_F_Revisitors', 
                        'Duration', 'Mouse_Clicks', 'Type']])
y = df['Group']
y_encoded = y.astype('category').cat.codes

x_train,x_test,y_train,y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

new_distribution = Counter(y_encoded)
print("Data Distribution:", new_distribution)

train_distribution = Counter(y_train)
print("Training Set Distribution:", train_distribution)

test_distribution = Counter(y_test)
print("Test Set Distribution:", test_distribution)
# Out:
# Data Distribution: Counter({6: 2684, 3: 2440, 8: 2440, 2: 2196, 7: 1464, 1: 1464, 5: 1220, 0: 732, 4: 488, 9: 244})
# Training Set Distribution: Counter({6: 1895, 3: 1707, 8: 1694, 2: 1493, 1: 1040, 7: 1035, 5: 856, 0: 513, 4: 355, 9: 172})
# Test Set Distribution: Counter({6: 789, 8: 746, 3: 733, 2: 703, 7: 429, 1: 424, 5: 364, 0: 219, 4: 133, 9: 72})

# %% [markdown]
# ### Random Forest Classifier

# %%
# ! pip install tensorflow
# !pip install lightgbm
import warnings
warnings.filterwarnings('ignore')

from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
import pandas as pd
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

print('Random Forest Classifier')
## Random Forest Classifier
rf_classifier = RandomForestClassifier()
## original parameter grid
param_grid = {
    'n_estimators': [int(x) for x in np.linspace(start=200, stop=2000, num=10)],  
    'max_features': [ 'sqrt', 'log2'],  
    'max_depth': [int(x) for x in np.linspace(50, 110, num=11)],
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'bootstrap': [True, False]  
}
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(
    estimator=rf_classifier,
    param_distributions=param_grid,
    n_iter=50,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'], 
    cv=stratified_kfold,
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,
    random_state=42,
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True 
)
random_search.fit(x_train,y_train)
print("Best Parameters:", random_search.best_params_)
rfc=random_search
# y_train[:5]
print('Train Report \n',classification_report(y_train,rfc.predict(x_train)))
print('Test Report\n',classification_report(y_test,rfc.predict(x_test)))
# Out:
# Random Forest Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  13.3s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   7.6s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.7s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  13.5s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   7.7s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.7s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  13.7s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   7.7s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.9s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  13.5s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   7.8s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.9s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  13.6s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   7.7s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.9s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   5.4s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  16.3s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   6.1s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.6s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  15.8s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  16.9s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.6s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  16.2s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   6.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.9s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  15.6s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  17.4s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   8.8s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   9.5s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  11.2s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  12.6s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  16.6s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  18.1s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  12.0s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  17.2s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   8.9s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  11.1s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  13.1s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  16.6s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  18.1s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  12.0s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  17.3s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.3s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   5.4s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.6s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.5s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   5.9s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  15.4s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   6.6s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.8s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   9.4s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   8.7s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  11.1s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  12.5s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  16.5s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  17.8s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  11.7s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   6.6s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=False, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=56, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  21.0s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=False, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=56, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  20.2s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   5.5s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.8s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  16.0s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   6.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.7s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  15.5s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  11.5s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   6.4s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=False, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=False, max_depth=56, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  20.6s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.6s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  15.0s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  15.0s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.5s
# [CV] END bootstrap=False, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=56, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  19.1s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   7.3s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.1s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  18.8s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  19.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   7.3s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  19.9s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   8.8s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   9.5s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  11.1s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  12.6s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  16.2s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  18.1s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  11.7s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   6.5s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.9s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   7.3s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.9s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.1s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  20.7s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  19.9s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.8s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   7.3s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.2s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.1s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   4.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.5s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   5.1s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  17.1s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.7s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.2s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  16.8s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   8.6s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=   9.7s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  11.0s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  12.9s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  17.1s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  17.5s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  12.3s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  17.5s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.5s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   7.6s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   3.9s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.2s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   5.2s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  17.7s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   9.6s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   7.7s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  15.8s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   9.7s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  16.8s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=  10.1s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  17.9s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=  10.1s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  18.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  17.5s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   5.4s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  16.0s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   6.1s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   4.7s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  15.3s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   6.7s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.3s
# [CV] END bootstrap=False, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=56, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  20.1s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.3s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.1s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.7s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.5s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   5.2s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   9.6s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   8.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  18.5s
# Best Parameters: {'n_estimators': 1800, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 56, 'bootstrap': False}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       513
#            1       0.97      0.96      0.97      1040
#            2       0.95      0.96      0.96      1493
#            3       0.97      0.97      0.97      1707
#            4       0.90      0.87      0.89       355
#            5       0.95      0.94      0.94       856
#            6       0.93      0.94      0.94      1895
#            7       0.91      0.96      0.93      1035
#            8       0.94      0.91      0.92      1694
#            9       0.97      0.89      0.93       172
#
#     accuracy                           0.95     10760
#    macro avg       0.95      0.94      0.94     10760
# weighted avg       0.95      0.95      0.95     10760
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.93      0.87       219
#            1       0.66      0.61      0.63       424
#            2       0.69      0.69      0.69       703
#            3       0.70      0.74      0.72       733
#            4       0.45      0.38      0.41       133
#            5       0.71      0.55      0.62       364
#            6       0.59      0.68      0.63       789
#            7       0.59      0.61      0.60       429
#            8       0.51      0.49      0.50       746
#            9       0.27      0.14      0.18        72
#
#     accuracy                           0.63      4612
#    macro avg       0.60      0.58      0.59      4612
# weighted avg       0.63      0.63      0.63      4612
#
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  16.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  15.8s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.6s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  15.8s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.0s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.7s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   7.3s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   5.1s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  16.4s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  16.1s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  16.4s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  16.7s

# %% [markdown]
# ### Decision Tree Classifier

# %%
print('Decision Tree Classifier')
## Decision Tree Classifier
dtc = DecisionTreeClassifier()
param_dist_dt = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None] + list(range(10, 101, 10)),
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10, 15],
    'max_features': ['auto', 'sqrt', 'log2', None],
}
random_model = RandomizedSearchCV(
    estimator=dtc,
    param_distributions=param_dist_dt,
    n_iter=200,  # Increase the number of iterations
    n_jobs=-1,
    verbose=2,
    random_state=42,
    cv=stratified_kfold,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    refit='f1_macro',
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model.fit(x_train, y_train)
print('Best Parameters', random_model.best_params_)
dtc=random_model
print('Train Report\n', classification_report(y_train, dtc.predict(x_train)))
print('Test Report\n', classification_report(y_test, dtc.predict(x_test)))
# Out:
# Decision Tree Classifier
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Parameters {'splitter': 'best', 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 40, 'criterion': 'entropy'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       513
#            1       0.94      0.96      0.95      1040
#            2       0.93      0.92      0.92      1493
#            3       0.95      0.96      0.96      1707
#            4       0.79      0.80      0.79       355
#            5       0.87      0.88      0.88       856
#            6       0.87      0.90      0.88      1895
#            7       0.84      0.89      0.86      1035
#            8       0.88      0.81      0.84      1694
#            9       0.81      0.66      0.72       172
#
#     accuracy                           0.90     10760
#    macro avg       0.88      0.88      0.88     10760
# weighted avg       0.90      0.90      0.90     10760
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       219
#            1       0.88      0.91      0.90       424
#            2       0.89      0.85      0.87       703
#            3       0.88      0.90      0.89       733
#            4       0.62      0.68      0.65       133
#            5       0.72      0.75      0.73       364
#            6       0.72      0.78      0.75       789
#            7       0.69      0.72      0.71       429
#            8       0.73      0.62      0.67       746
#            9       0.53      0.49      0.51        72
#
#     accuracy                           0.79      4612
#    macro avg       0.76      0.76      0.76      4612
# weighted avg       0.79      0.79      0.79      4612

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
features = X
target = y_encoded
target=pd.get_dummies(target)

print('Gradient Boosting Classifier')
## Gradient Boosting Classifier
gbc=GradientBoostingClassifier()
param_grid={
    'max_features': ['sqrt','log2'],
    'max_depth': range(3,10),
    'min_samples_leaf': [3,5,7],
    'min_samples_split': range(2,10),
    'loss':['deviance','log_loss','exponential'],
    'learning_rate':[0.1,0.01,0.001],
    'n_estimators':[100,200,300,400,500]
}

random_model_gbc=RandomizedSearchCV(
    estimator=gbc,
    param_distributions=param_grid,
    verbose=2,
    n_jobs=-1,
    scoring=['precision_macro','recall_macro','f1_weighted'],
    refit='f1_weighted',
    cv=stratified_kfold,
    n_iter=100,
    random_state=42,
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model_gbc.fit(x_train,y_train)
print('Best Parameters ',random_model_gbc.best_params_)
print('Train, Report\n',classification_report(y_train,random_model_gbc.predict(x_train)))
print('Test, Report\n',classification_report(y_test,random_model_gbc.predict(x_test)))

# %% [markdown]
# ### Light Gradient Boosting Classifier

# %%
print('Light Gradient Boosting Classifier')
## Light Gradient Boosting Classifier
lgb_classifier = lgb.LGBMClassifier()
param_grid = {
    'boosting_type': ['gbdt', 'dart', 'goss'],
    'num_leaves': [15, 31, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'objective': ['multiclass'],  # for multiclass classification
    'random_state': [42],
}

random_search = RandomizedSearchCV(
    estimator=lgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

# Fit the RandomizedSearchCV object to the data
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# Light Gradient Boosting Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END learning_rate=0.01, loss=exponential, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=  19.1s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=8, n_estimators=500; total time=  42.5s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=8, n_estimators=500; total time=  43.1s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=100; total time=   7.3s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  20.7s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=100; total time=  11.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=400; total time=  45.2s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   3.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time=   9.6s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=None, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=None, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=8, n_estimators=100; total time=   4.7s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   7.7s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   7.7s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   9.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   9.2s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  20.8s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=400; total time=  35.1s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=  30.4s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   9.2s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100; total time=   8.8s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=  18.4s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  14.5s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=9, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=400; total time=  36.5s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=9, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=400; total time=  36.9s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=100; total time=   4.6s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=400; total time=  15.2s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=200; total time=  12.1s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   9.1s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  11.3s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=200; total time=  14.3s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   6.1s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=8, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=100; total time=   5.1s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   7.5s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=400; total time=  15.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=100; total time=   7.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   3.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time=   9.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=None, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=None, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=auto, min_samples_leaf=15, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=auto, min_samples_leaf=15, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=auto, min_samples_leaf=15, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   6.6s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=100; total time=   9.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=100; total time=   9.4s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.1, loss=exponential, max_depth=7, max_features=sqrt, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=   0.0s
# ...
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=   6.1s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.2s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=31, objective=multiclass, random_state=42; total time=   3.5s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   4.1s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   0.8s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.1min
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=15, objective=multiclass, random_state=42; total time=   3.2s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=   5.9s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.9s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   6.5s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.3s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.4s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   7.1s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   5.0s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=15, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.3s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=31, objective=multiclass, random_state=42; total time=   3.7s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   4.1s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.4s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.2min
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=15, objective=multiclass, random_state=42; total time=   3.0s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=   6.0s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   5.1s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   6.9s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.3s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   7.1s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   2.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   5.0s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.3s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.3s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.1min
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.4s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.2s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.5s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=15, objective=multiclass, random_state=42; total time=   3.0s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=   6.0s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   5.1s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   6.8s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.1s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.3s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.4s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   7.0s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   5.2s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  23.0s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.8s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.9s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.0s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  29.4s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   5.1s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   7.0s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.4s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   7.3s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   5.2s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  23.5s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   3.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   5.0s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.1s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  29.7s
# Best Parameters: {'random_state': 42, 'objective': 'multiclass', 'num_leaves': 31, 'n_estimators': 50, 'learning_rate': 0.2, 'boosting_type': 'dart'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       513
#            1       0.90      0.87      0.89      1040
#            2       0.87      0.82      0.84      1493
#            3       0.93      0.90      0.91      1707
#            4       0.86      0.86      0.86       355
#            5       0.89      0.85      0.87       856
#            6       0.81      0.87      0.84      1895
#            7       0.81      0.88      0.84      1035
#            8       0.80      0.79      0.80      1694
#            9       0.94      0.89      0.91       172
#
#     accuracy                           0.86     10760
#    macro avg       0.88      0.87      0.87     10760
# weighted avg       0.86      0.86      0.86     10760
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       219
#            1       0.81      0.81      0.81       424
#            2       0.81      0.73      0.77       703
#            3       0.87      0.85      0.86       733
#            4       0.67      0.69      0.68       133
#            5       0.75      0.71      0.73       364
#            6       0.71      0.80      0.75       789
#            7       0.70      0.72      0.71       429
#            8       0.67      0.66      0.66       746
#            9       0.52      0.44      0.48        72
#
#     accuracy                           0.76      4612
#    macro avg       0.74      0.74      0.74      4612
# weighted avg       0.76      0.76      0.76      4612

# %% [markdown]
# ### XGBoost classifier

# %%
print('XGBoost classifier')
# XGBoost classifier
xgb_classifier = xgb.XGBClassifier()

param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage used to prevent overfitting
    'max_depth': [3, 5, 7], 
    'min_child_weight': [1, 3, 5],  
    'subsample': [0.8, 0.9, 1.0],  
    'colsample_bytree': [0.8, 0.9, 1.0], 
    'gamma': [0, 0.1, 0.2], 
    'objective': ['multi:softmax'],  # for multiclass classification
    'num_class': [len(set(y_train))]  # Number of classes
}

random_search = RandomizedSearchCV(
    estimator=xgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro','recall_macro','f1_macro'],  # Use accuracy as the scoring metric
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

random_search.fit(x_train, y_train)
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# XGBoost classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.1min
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  23.3s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.8s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   2.8s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.1s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.8s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  29.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.3s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.5s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  43.4s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  47.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.1s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.2min
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  23.3s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   3.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.9s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.0s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  29.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 3.4min
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.8s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   6.9s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.4s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.8s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   2.0s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   5.6s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  22.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  40.5s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  46.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 3.4min
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.6s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  41.4s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  46.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 3.4min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 2.0min
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.5s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  41.5s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  46.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 3.4min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  17.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=   8.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  15.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.3s
# Best Parameters: {'subsample': 1.0, 'objective': 'multi:softmax', 'num_class': 10, 'n_estimators': 300, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.2, 'gamma': 0, 'colsample_bytree': 0.8}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       513
#            1       0.99      0.89      0.93      1040
#            2       0.96      0.84      0.90      1493
#            3       0.94      0.93      0.93      1707
#            4       0.77      0.74      0.75       355
#            5       0.83      0.82      0.82       856
#            6       0.79      0.85      0.82      1895
#            7       0.75      0.84      0.79      1035
#            8       0.75      0.76      0.76      1694
#            9       0.82      0.78      0.80       172
#
#     accuracy                           0.85     10760
#    macro avg       0.85      0.84      0.85     10760
# weighted avg       0.86      0.85      0.85     10760
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       219
#            1       0.97      0.87      0.91       424
#            2       0.96      0.81      0.88       703
#            3       0.92      0.89      0.90       733
#            4       0.63      0.66      0.65       133
#            5       0.75      0.74      0.75       364
#            6       0.72      0.85      0.78       789
#            7       0.70      0.75      0.72       429
#            8       0.69      0.68      0.69       746
#            9       0.51      0.43      0.47        72
#
#     accuracy                           0.80      4612
#    macro avg       0.77      0.77      0.77      4612
# weighted avg       0.81      0.80      0.80      4612

# %% [markdown]
# # OverSampling and UnderSampling

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from imblearn.pipeline import Pipeline 


#Oversampling class 4,9
class_9_label = y_encoded[y == 'resident'].iloc[0]
class_4_label = y_encoded[y == 'General Doctor'].iloc[0]  

desired_number_of_samples = 2000

oversample_strategy = {class_9_label: desired_number_of_samples, class_4_label: desired_number_of_samples}

#Undersampling majority classes
undersample_strategy = {label: min(desired_number_of_samples, count) for label, count in Counter(y_encoded).items() if label not in [class_9_label, class_4_label]}

resample_pipeline = Pipeline([
    ('oversample', SMOTE(sampling_strategy=oversample_strategy)),
    ('undersample', RandomUnderSampler(sampling_strategy=undersample_strategy))
])

X_resampled, y_resampled = resample_pipeline.fit_resample(X, y_encoded)

x_train,x_test,y_train,y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

new_distribution = Counter(y_resampled)
print("Resampled Data Distribution:", new_distribution)

train_distribution = Counter(y_train)
print("Training Set Distribution:", train_distribution)

test_distribution = Counter(y_test)
print("Test Set Distribution:", test_distribution)
# Out:
# Resampled Data Distribution: Counter({2: 2000, 3: 2000, 4: 2000, 6: 2000, 8: 2000, 9: 2000, 1: 1464, 7: 1464, 5: 1220, 0: 732})
# Training Set Distribution: Counter({8: 1410, 9: 1405, 3: 1402, 4: 1398, 6: 1396, 2: 1371, 1: 1039, 7: 1036, 5: 845, 0: 514})
# Test Set Distribution: Counter({2: 629, 6: 604, 4: 602, 3: 598, 9: 595, 8: 590, 7: 428, 1: 425, 5: 375, 0: 218})

# %%
# ! pip install tensorflow
# !pip install lightgbm
import warnings
warnings.filterwarnings('ignore')

from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
import pandas as pd
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

print('Random Forest Classifier')
## Random Forest Classifier
rf_classifier = RandomForestClassifier()
## original parameter grid
param_grid = {
    'n_estimators': [int(x) for x in np.linspace(start=200, stop=2000, num=10)],  
    'max_features': [ 'sqrt', 'log2'],  
    'max_depth': [int(x) for x in np.linspace(50, 110, num=11)],
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'bootstrap': [True, False]  
}
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(
    estimator=rf_classifier,
    param_distributions=param_grid,
    n_iter=50,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'], 
    cv=stratified_kfold,
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,
    random_state=42,
     error_score=np.nan,  
    return_train_score=True 
)
random_search.fit(x_train,y_train)
print("Best Parameters:", random_search.best_params_)
rfc=random_search
# y_train[:5]
print('Train Report \n',classification_report(y_train,rfc.predict(x_train)))
print('Test Report\n',classification_report(y_test,rfc.predict(x_test)))
# Out:
# Random Forest Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  19.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  17.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  18.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  14.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.0s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.1s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   9.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.8s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  16.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.3s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=   9.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  19.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  17.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   6.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=   8.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  15.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.2s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  19.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.6min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   5.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  17.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  14.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  15.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.4s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   3.0s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   4.7s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.1s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   1.9s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  29.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  18.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  17.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  16.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  15.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.2s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  14.9s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   4.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   6.5s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  41.0s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  46.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 3.4min
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  18.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  14.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.1s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  14.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  16.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  15.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.4s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  15.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  19.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  17.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  16.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  11.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.1s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  15.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  17.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  14.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  15.3s
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  15.2s
# [CV] END bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.0s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  10.8s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  13.6s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   8.9s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  11.2s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   9.0s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  12.2s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   8.9s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   9.1s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  12.3s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   9.0s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  12.7s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.3s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  10.2s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  21.1s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   7.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  22.1s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  19.9s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.4s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  10.3s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  21.4s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   7.3s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  21.6s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  19.9s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  10.0s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  20.2s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   7.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  21.2s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  13.7s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.3s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  17.6s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.2s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=  10.0s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  20.2s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   7.3s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.6s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  18.0s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  13.7s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.2s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  17.9s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.2s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.0s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  17.7s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  18.3s
# Best Parameters: {'n_estimators': 1800, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 56, 'bootstrap': False}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       514
#            1       0.98      0.96      0.97      1039
#            2       0.95      0.96      0.95      1371
#            3       0.98      0.98      0.98      1402
#            4       0.90      0.98      0.94      1398
#            5       0.96      0.93      0.94       845
#            6       0.94      0.91      0.93      1396
#            7       0.95      0.93      0.94      1036
#            8       0.94      0.90      0.92      1410
#            9       0.97      0.98      0.98      1405
#
#     accuracy                           0.95     11816
#    macro avg       0.95      0.95      0.95     11816
# weighted avg       0.95      0.95      0.95     11816
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       218
#            1       0.61      0.62      0.62       425
#            2       0.71      0.68      0.69       629
#            3       0.67      0.69      0.68       598
#            4       0.79      0.88      0.83       602
#            5       0.74      0.57      0.64       375
#            6       0.58      0.56      0.57       604
#            7       0.67      0.63      0.65       428
#            8       0.44      0.43      0.44       590
#            9       0.82      0.93      0.87       595
#
#     accuracy                           0.68      5064
#    macro avg       0.69      0.68      0.68      5064
# weighted avg       0.68      0.68      0.68      5064

# %%
print('Decision Tree Classifier')
## Decision Tree Classifier
dtc = DecisionTreeClassifier()
param_dist_dt = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None] + list(range(10, 101, 10)),
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10, 15],
    'max_features': ['auto', 'sqrt', 'log2', None],
}
random_model = RandomizedSearchCV(
    estimator=dtc,
    param_distributions=param_dist_dt,
    n_iter=200,  # Increase the number of iterations
    n_jobs=-1,
    verbose=2,
    random_state=42,
    cv=stratified_kfold,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    refit='f1_macro',
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model.fit(x_train, y_train)
print('Best Parameters', random_model.best_params_)
dtc=random_model
print('Train Report\n', classification_report(y_train, dtc.predict(x_train)))
print('Test Report\n', classification_report(y_test, dtc.predict(x_test)))
# Out:
# Decision Tree Classifier
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Parameters {'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 40, 'criterion': 'entropy'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       514
#            1       0.98      0.98      0.98      1039
#            2       0.96      0.97      0.96      1371
#            3       0.99      0.98      0.98      1402
#            4       0.90      0.99      0.94      1398
#            5       0.96      0.93      0.95       845
#            6       0.95      0.92      0.94      1396
#            7       0.95      0.93      0.94      1036
#            8       0.96      0.91      0.93      1410
#            9       0.98      0.98      0.98      1405
#
#     accuracy                           0.96     11816
#    macro avg       0.96      0.96      0.96     11816
# weighted avg       0.96      0.96      0.96     11816
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       218
#            1       0.88      0.90      0.89       425
#            2       0.83      0.85      0.84       629
#            3       0.86      0.88      0.87       598
#            4       0.77      0.82      0.80       602
#            5       0.75      0.68      0.71       375
#            6       0.70      0.68      0.69       604
#            7       0.71      0.68      0.69       428
#            8       0.63      0.62      0.63       590
#            9       0.82      0.82      0.82       595
#
#     accuracy                           0.78      5064
#    macro avg       0.79      0.78      0.78      5064
# weighted avg       0.78      0.78      0.78      5064
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
features = X_resampled
target = y_resampled
target=pd.get_dummies(target)

print('Gradient Boosting Classifier')
## Gradient Boosting Classifier
gbc=GradientBoostingClassifier()
param_grid={
    'max_features': ['sqrt','log2'],
    'max_depth': range(3,10),
    'min_samples_leaf': [3,5,7],
    'min_samples_split': range(2,10),
    'loss':['deviance','log_loss','exponential'],
    'learning_rate':[0.1,0.01,0.001],
    'n_estimators':[100,200,300,400,500]
}

random_model_gbc=RandomizedSearchCV(
    estimator=gbc,
    param_distributions=param_grid,
    verbose=2,
    n_jobs=-1,
    scoring=['precision_macro','recall_macro','f1_weighted'],
    refit='f1_weighted',
    cv=stratified_kfold,
    n_iter=100,
    random_state=42,
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model_gbc.fit(x_train,y_train)
print('Best Parameters ',random_model_gbc.best_params_)
print('Train, Report\n',classification_report(y_train,random_model_gbc.predict(x_train)))
print('Test, Report\n',classification_report(y_test,random_model_gbc.predict(x_test)))
# Out:
# Gradient Boosting Classifier
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Parameters  {'n_estimators': 500, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': 6, 'loss': 'deviance', 'learning_rate': 0.1}
# Train, Report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       514
#            1       1.00      0.96      0.98      1039
#            2       0.98      0.94      0.96      1371
#            3       0.99      0.97      0.98      1402
#            4       0.90      0.99      0.94      1398
#            5       0.95      0.94      0.95       845
#            6       0.95      0.92      0.93      1396
#            7       0.94      0.94      0.94      1036
#            8       0.93      0.92      0.92      1410
#            9       0.97      0.98      0.98      1405
#
#     accuracy                           0.95     11816
#    macro avg       0.96      0.96      0.96     11816
# weighted avg       0.95      0.95      0.95     11816
#
# Test, Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       218
#            1       0.81      0.78      0.79       425
#            2       0.84      0.76      0.80       629
#            3       0.77      0.80      0.78       598
#            4       0.82      0.89      0.85       602
#            5       0.78      0.63      0.70       375
#            6       0.66      0.67      0.67       604
#            7       0.72      0.69      0.71       428
#            8       0.55      0.60      0.58       590
#            9       0.87      0.92      0.89       595
#
#     accuracy                           0.76      5064
#    macro avg       0.77      0.76      0.77      5064
# weighted avg       0.76      0.76      0.76      5064

# %%
print('Light Gradient Boosting Classifier')
## Light Gradient Boosting Classifier
lgb_classifier = lgb.LGBMClassifier()
param_grid = {
    'boosting_type': ['gbdt', 'dart', 'goss'],
    'num_leaves': [15, 31, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'objective': ['multiclass'],  # for multiclass classification
    'random_state': [42],
}

random_search = RandomizedSearchCV(
    estimator=lgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

# Fit the RandomizedSearchCV object to the data
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# Light Gradient Boosting Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Parameters: {'random_state': 42, 'objective': 'multiclass', 'num_leaves': 31, 'n_estimators': 300, 'learning_rate': 0.1, 'boosting_type': 'dart'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       514
#            1       0.90      0.92      0.91      1039
#            2       0.89      0.88      0.88      1371
#            3       0.95      0.90      0.93      1402
#            4       0.87      0.98      0.92      1398
#            5       0.92      0.89      0.90       845
#            6       0.89      0.83      0.86      1396
#            7       0.86      0.92      0.89      1036
#            8       0.89      0.82      0.85      1410
#            9       0.95      0.97      0.96      1405
#
#     accuracy                           0.90     11816
#    macro avg       0.91      0.91      0.91     11816
# weighted avg       0.90      0.90      0.90     11816
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       218
#            1       0.74      0.78      0.76       425
#            2       0.76      0.74      0.75       629
#            3       0.85      0.84      0.85       598
#            4       0.81      0.92      0.86       602
#            5       0.78      0.71      0.75       375
#            6       0.78      0.71      0.74       604
#            7       0.70      0.75      0.72       428
#            8       0.68      0.58      0.63       590
#            9       0.85      0.93      0.89       595
#
#     accuracy                           0.78      5064
#    macro avg       0.79      0.79      0.79      5064
# weighted avg       0.78      0.78      0.78      5064

# %%
print('XGBoost classifier')
# XGBoost classifier
xgb_classifier = xgb.XGBClassifier()

param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage used to prevent overfitting
    'max_depth': [3, 5, 7],  # Maximum depth of a tree
    'min_child_weight': [1, 3, 5],  # Minimum sum of instance weight needed in a child
    'subsample': [0.8, 0.9, 1.0],  # Subsample ratio of the training instances
    'colsample_bytree': [0.8, 0.9, 1.0],  # Subsample ratio of columns when constructing each tree
    'gamma': [0, 0.1, 0.2],  # Minimum loss reduction required to make a further partition on a leaf node of the tree
    'objective': ['multi:softmax'],  # for multiclass classification
    'num_class': [len(set(y_train))]  # Number of classes
}

random_search = RandomizedSearchCV(
    estimator=xgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro','recall_macro','f1_macro'],  # Use accuracy as the scoring metric
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

random_search.fit(x_train, y_train)
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# XGBoost classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Parameters: {'subsample': 1.0, 'objective': 'multi:softmax', 'num_class': 10, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0.1, 'colsample_bytree': 0.8}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       514
#            1       0.99      0.95      0.97      1039
#            2       0.96      0.91      0.93      1371
#            3       0.97      0.94      0.95      1402
#            4       0.87      0.98      0.92      1398
#            5       0.91      0.86      0.89       845
#            6       0.89      0.86      0.87      1396
#            7       0.85      0.91      0.88      1036
#            8       0.87      0.83      0.85      1410
#            9       0.95      0.97      0.96      1405
#
#     accuracy                           0.92     11816
#    macro avg       0.92      0.92      0.92     11816
# weighted avg       0.92      0.92      0.92     11816
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       218
#            1       0.91      0.89      0.90       425
#            2       0.91      0.83      0.87       629
#            3       0.90      0.89      0.89       598
#            4       0.81      0.91      0.86       602
#            5       0.81      0.70      0.75       375
#            6       0.75      0.74      0.74       604
#            7       0.70      0.76      0.73       428
#            8       0.69      0.63      0.66       590
#            9       0.86      0.93      0.89       595
#
#     accuracy                           0.82      5064
#    macro avg       0.82      0.82      0.82      5064
# weighted avg       0.82      0.82      0.82      5064
#
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  11.0s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  14.4s
# [CV] END bootstrap=True, max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  15.6s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=  22.3s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  22.1s
# [CV] END bootstrap=False, max_depth=68, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  14.7s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  14.1s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   7.9s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  17.2s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  11.3s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   8.5s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  19.2s
# [CV] END bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   5.0s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   4.2s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   9.3s
# [CV] END bootstrap=False, max_depth=110, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   6.1s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=  21.5s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=  20.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=15, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=10, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=15, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=70, max_features=None, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=None, min_samples_leaf=10, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=None, min_samples_leaf=5, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=8, n_estimators=100; total time=   5.1s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=9, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.7s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   9.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=  10.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=7, n_estimators=200; total time=  10.2s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  25.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=9, max_features=sqrt, min_samples_leaf=7, min_samples_split=9, n_estimators=200; total time=  23.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=  17.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=500; total time=  34.9s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=  10.4s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100; total time=  10.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=  20.2s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  17.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  28.7s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=9, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=400; total time=  41.2s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  18.5s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=400; total time=  17.5s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=200; total time=  14.3s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=200; total time=  10.3s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  13.1s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=100; total time=  12.2s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=400; total time=  53.6s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   2.8s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=  31.0s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=15, objective=multiclass, random_state=42; total time=   1.2s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.5s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=31, objective=multiclass, random_state=42; total time=   4.3s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   5.2s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.0s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   5.0s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time= 1.2min
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.4s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=  27.1s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.3s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.4s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   3.5s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   3.5s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   5.6s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=100, num_leaves=100, objective=multiclass, random_state=42; total time=   2.5s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=  31.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=  10.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  15.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  12.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  30.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  13.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  21.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  17.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  13.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  17.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.6s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  18.2s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.7s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=False, max_depth=86, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  18.7s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=56, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=  24.0s
# [CV] END bootstrap=True, max_depth=74, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=  12.2s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   9.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=92, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1800; total time=  21.2s
# [CV] END criterion=entropy, max_depth=60, max_features=auto, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=70, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=70, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=15, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=15, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=15, min_samples_split=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=60, max_features=log2, min_samples_leaf=2, min_samples_split=15, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=100, max_features=auto, min_samples_leaf=15, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=auto, min_samples_leaf=5, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=60, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=auto, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=40, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=80, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=90, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best; total time=   0.0s
# [CV] END criterion=gini, max_depth=90, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, splitter=best; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=100, max_features=log2, min_samples_leaf=2, min_samples_split=20, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=80, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   0.0s
# ...
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=  10.2s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100; total time=  10.1s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=  20.1s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=log_loss, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  17.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  28.8s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=8, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  29.2s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=8, n_estimators=400; total time=  20.4s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  18.2s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=  17.6s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=6, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.1, loss=log_loss, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=log_loss, max_depth=4, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=100; total time=   8.3s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=100; total time=   8.5s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  24.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=200; total time=  16.7s
# [CV] END learning_rate=0.001, loss=deviance, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   7.4s
# [CV] END learning_rate=0.01, loss=deviance, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=100; total time=   6.5s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   9.2s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=100; total time=   8.8s
# [CV] END learning_rate=0.1, loss=deviance, max_depth=7, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=100; total time=   9.2s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, loss=exponential, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END boosting_type=gbdt, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   3.7s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time=  12.1s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.9s
# [CV] END boosting_type=goss, learning_rate=0.2, n_estimators=50, num_leaves=31, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=300, num_leaves=100, objective=multiclass, random_state=42; total time=   7.8s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   0.9s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=200, num_leaves=31, objective=multiclass, random_state=42; total time=   2.7s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  50.7s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=100, objective=multiclass, random_state=42; total time=   7.8s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   5.5s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=100, num_leaves=50, objective=multiclass, random_state=42; total time=   8.0s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.9s
# [CV] END boosting_type=dart, learning_rate=0.01, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.6s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   2.8s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=200, num_leaves=15, objective=multiclass, random_state=42; total time=   1.9s
# [CV] END boosting_type=goss, learning_rate=0.05, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   8.9s
# [CV] END boosting_type=gbdt, learning_rate=0.2, n_estimators=300, num_leaves=15, objective=multiclass, random_state=42; total time=   2.2s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=   6.7s
# [CV] END boosting_type=gbdt, learning_rate=0.05, n_estimators=50, num_leaves=100, objective=multiclass, random_state=42; total time=   1.3s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=200, num_leaves=50, objective=multiclass, random_state=42; total time=   5.7s
# [CV] END boosting_type=gbdt, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.1s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   1.8s
# [CV] END boosting_type=goss, learning_rate=0.01, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=   7.6s
# [CV] END boosting_type=goss, learning_rate=0.1, n_estimators=100, num_leaves=31, objective=multiclass, random_state=42; total time=   2.0s
# [CV] END boosting_type=dart, learning_rate=0.05, n_estimators=50, num_leaves=50, objective=multiclass, random_state=42; total time=   1.7s
# [CV] END boosting_type=dart, learning_rate=0.1, n_estimators=300, num_leaves=31, objective=multiclass, random_state=42; total time=  49.7s
# [CV] END boosting_type=dart, learning_rate=0.2, n_estimators=300, num_leaves=50, objective=multiclass, random_state=42; total time=  57.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  19.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  22.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  20.9s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  12.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   7.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  11.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  18.8s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=   8.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=  18.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=0.9; total time=   8.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=200, num_class=10, objective=multi:softmax, subsample=1.0; total time=  12.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=1.0; total time=  18.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, num_class=10, objective=multi:softmax, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, num_class=10, objective=multi:softmax, subsample=0.9; total time=  18.1s

# %% [markdown]
# # OverSampling

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from imblearn.pipeline import Pipeline 

class_9_label = y_encoded[y == 'resident'].iloc[0]
class_4_label = y_encoded[y == 'General Doctor'].iloc[0]  
class_0_label = y_encoded[y == 'CCU Nurse'].iloc[0]


# desired_number_of_samples = 1500

oversample_strategy = {class_9_label: 600, class_4_label: 1500, class_0_label: 1500}

undersample_strategy = {label: count for label, count in Counter(y_encoded).items() if label not in [class_9_label, class_4_label, class_0_label]}

resample_pipeline = Pipeline([
    ('oversample', SMOTE(sampling_strategy=oversample_strategy)),
    ('undersample', RandomUnderSampler(sampling_strategy=undersample_strategy))
])

X_resampled, y_resampled = resample_pipeline.fit_resample(X, y_encoded)

x_train,x_test,y_train,y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

new_distribution = Counter(y_resampled)
print("Resampled Data Distribution:", new_distribution)

train_distribution = Counter(y_train)
print("Training Set Distribution:", train_distribution)

test_distribution = Counter(y_test)
print("Test Set Distribution:", test_distribution)
# Out:
# Resampled Data Distribution: Counter({6: 2684, 3: 2440, 8: 2440, 2: 2196, 0: 1500, 4: 1500, 1: 1464, 7: 1464, 5: 1220, 9: 600})
# Training Set Distribution: Counter({6: 1876, 8: 1739, 3: 1724, 2: 1538, 0: 1053, 4: 1033, 1: 1017, 7: 1003, 5: 856, 9: 416})
# Test Set Distribution: Counter({6: 808, 3: 716, 8: 701, 2: 658, 4: 467, 7: 461, 1: 447, 0: 447, 5: 364, 9: 184})

# %%
# ! pip install tensorflow
# !pip install lightgbm
import warnings
warnings.filterwarnings('ignore')

from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
import pandas as pd
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold


print('Random Forest Classifier')
## Random Forest Classifier
rf_classifier = RandomForestClassifier()

param_grid = {
    'n_estimators': [int(x) for x in np.linspace(start=200, stop=2000, num=10)],  
    'max_features': [ 'sqrt', 'log2'],  
    'max_depth': [int(x) for x in np.linspace(50, 110, num=11)],
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'bootstrap': [True, False]  
}
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(
    estimator=rf_classifier,
    param_distributions=param_grid,
    n_iter=50,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'], 
    cv=stratified_kfold,
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,
    random_state=42,
     error_score=np.nan, 
    return_train_score=True 
)
random_search.fit(x_train,y_train)
print("Best Parameters:", random_search.best_params_)
rfc=random_search
# y_train[:5]
print('Train Report \n',classification_report(y_train,rfc.predict(x_train)))
print('Test Report\n',classification_report(y_test,rfc.predict(x_test)))
# Out:
# Random Forest Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=2000; total time=  16.0s
# [CV] END bootstrap=True, max_depth=74, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=   8.7s
# [CV] END bootstrap=False, max_depth=86, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=False, max_depth=74, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   6.4s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   9.2s
# [CV] END bootstrap=False, max_depth=98, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=  19.9s
# [CV] END bootstrap=True, max_depth=56, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   7.7s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=False, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=  22.7s
# [CV] END bootstrap=False, max_depth=62, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=  15.1s
# [CV] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   8.1s
# [CV] END bootstrap=True, max_depth=86, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=False, max_depth=98, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  21.2s
# [CV] END bootstrap=True, max_depth=98, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=104, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200; total time=  10.8s
# [CV] END bootstrap=True, max_depth=56, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, max_depth=92, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=  20.2s
# Best Parameters: {'n_estimators': 1800, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 56, 'bootstrap': False}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1053
#            1       0.98      0.96      0.97      1017
#            2       0.96      0.95      0.96      1538
#            3       0.97      0.98      0.97      1724
#            4       0.91      0.96      0.93      1033
#            5       0.95      0.92      0.93       856
#            6       0.94      0.94      0.94      1876
#            7       0.91      0.94      0.92      1003
#            8       0.95      0.90      0.92      1739
#            9       0.96      0.95      0.96       416
#
#     accuracy                           0.95     12255
#    macro avg       0.95      0.95      0.95     12255
# weighted avg       0.95      0.95      0.95     12255
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       447
#            1       0.65      0.62      0.63       447
#            2       0.74      0.68      0.71       658
#            3       0.69      0.71      0.70       716
#            4       0.77      0.80      0.78       467
#            5       0.75      0.55      0.63       364
#            6       0.60      0.66      0.63       808
#            7       0.65      0.64      0.65       461
#            8       0.49      0.50      0.49       701
#            9       0.68      0.66      0.67       184
#
#     accuracy                           0.67      5253
#    macro avg       0.69      0.68      0.68      5253
# weighted avg       0.68      0.67      0.67      5253

# %%
print('Decision Tree Classifier')
## Decision Tree Classifier
dtc = DecisionTreeClassifier()
param_dist_dt = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None] + list(range(10, 101, 10)),
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10, 15],
    'max_features': ['auto', 'sqrt', 'log2', None],
}
random_model = RandomizedSearchCV(
    estimator=dtc,
    param_distributions=param_dist_dt,
    n_iter=200,  # Increase the number of iterations
    n_jobs=-1,
    verbose=2,
    random_state=42,
    cv=stratified_kfold,
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    refit='f1_macro',
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model.fit(x_train, y_train)
print('Best Parameters', random_model.best_params_)
dtc=random_model
print('Train Report\n', classification_report(y_train, dtc.predict(x_train)))
print('Test Report\n', classification_report(y_test, dtc.predict(x_test)))
# Out:
# Decision Tree Classifier
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Parameters {'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 40, 'criterion': 'entropy'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1053
#            1       0.99      0.98      0.98      1017
#            2       0.96      0.96      0.96      1538
#            3       0.97      0.99      0.98      1724
#            4       0.92      0.96      0.94      1033
#            5       0.95      0.93      0.94       856
#            6       0.95      0.94      0.95      1876
#            7       0.91      0.95      0.93      1003
#            8       0.96      0.90      0.93      1739
#            9       0.97      0.95      0.96       416
#
#     accuracy                           0.95     12255
#    macro avg       0.95      0.96      0.96     12255
# weighted avg       0.96      0.95      0.95     12255
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       447
#            1       0.88      0.87      0.88       447
#            2       0.88      0.88      0.88       658
#            3       0.88      0.89      0.88       716
#            4       0.76      0.74      0.75       467
#            5       0.73      0.69      0.71       364
#            6       0.73      0.75      0.74       808
#            7       0.69      0.70      0.70       461
#            8       0.65      0.64      0.64       701
#            9       0.61      0.63      0.62       184
#
#     accuracy                           0.78      5253
#    macro avg       0.77      0.77      0.77      5253
# weighted avg       0.78      0.78      0.78      5253

# %%
features = X_resampled
target = y_resampled
target=pd.get_dummies(target)

print('Gradient Boosting Classifier')
## Gradient Boosting Classifier
gbc=GradientBoostingClassifier()
param_grid={
    'max_features': ['sqrt','log2'],
    'max_depth': range(3,10),
    'min_samples_leaf': [3,5,7],
    'min_samples_split': range(2,10),
    'loss':['deviance','log_loss','exponential'],
    'learning_rate':[0.1,0.01,0.001],
    'n_estimators':[100,200,300,400,500]
}

random_model_gbc=RandomizedSearchCV(
    estimator=gbc,
    param_distributions=param_grid,
    verbose=2,
    n_jobs=-1,
    scoring=['precision_macro','recall_macro','f1_weighted'],
    refit='f1_weighted',
    cv=stratified_kfold,
    n_iter=100,
    random_state=42,
     error_score=np.nan,  # Set error_score to NaN to handle UndefinedMetricWarning
    return_train_score=True
)

random_model_gbc.fit(x_train,y_train)
print('Best Parameters ',random_model_gbc.best_params_)
print('Train, Report\n',classification_report(y_train,random_model_gbc.predict(x_train)))
print('Test, Report\n',classification_report(y_test,random_model_gbc.predict(x_test)))
# Out:
# Gradient Boosting Classifier
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/tejaswini/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Parameters  {'n_estimators': 500, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': 6, 'loss': 'deviance', 'learning_rate': 0.1}
# Train, Report
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1053
#            1       0.99      0.97      0.98      1017
#            2       0.99      0.93      0.96      1538
#            3       0.97      0.98      0.98      1724
#            4       0.94      0.95      0.94      1033
#            5       0.95      0.93      0.94       856
#            6       0.92      0.94      0.93      1876
#            7       0.89      0.96      0.92      1003
#            8       0.94      0.91      0.92      1739
#            9       0.93      0.98      0.96       416
#
#     accuracy                           0.95     12255
#    macro avg       0.95      0.95      0.95     12255
# weighted avg       0.95      0.95      0.95     12255
#
# Test, Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       447
#            1       0.79      0.76      0.78       447
#            2       0.84      0.73      0.78       658
#            3       0.81      0.82      0.82       716
#            4       0.86      0.79      0.82       467
#            5       0.76      0.65      0.70       364
#            6       0.68      0.77      0.72       808
#            7       0.68      0.69      0.69       461
#            8       0.56      0.62      0.59       701
#            9       0.73      0.65      0.69       184
#
#     accuracy                           0.75      5253
#    macro avg       0.76      0.74      0.75      5253
# weighted avg       0.75      0.75      0.75      5253

# %%
print('XGBoost classifier')
# XGBoost classifier
xgb_classifier = xgb.XGBClassifier()

param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage used to prevent overfitting
    'max_depth': [3, 5, 7],  # Maximum depth of a tree
    'min_child_weight': [1, 3, 5],  # Minimum sum of instance weight needed in a child
    'subsample': [0.8, 0.9, 1.0],  # Subsample ratio of the training instances
    'colsample_bytree': [0.8, 0.9, 1.0],  # Subsample ratio of columns when constructing each tree
    'gamma': [0, 0.1, 0.2],  # Minimum loss reduction required to make a further partition on a leaf node of the tree
    'objective': ['multi:softmax'],  # for multiclass classification
    'num_class': [len(set(y_train))]  # Number of classes
}

random_search = RandomizedSearchCV(
    estimator=xgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro','recall_macro','f1_macro'],  # Use accuracy as the scoring metric
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

random_search.fit(x_train, y_train)
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# XGBoost classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Parameters: {'subsample': 0.9, 'objective': 'multi:softmax', 'num_class': 10, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 7, 'learning_rate': 0.2, 'gamma': 0.2, 'colsample_bytree': 0.9}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1053
#            1       0.98      0.95      0.97      1017
#            2       0.95      0.91      0.93      1538
#            3       0.96      0.95      0.96      1724
#            4       0.90      0.94      0.92      1033
#            5       0.93      0.87      0.90       856
#            6       0.89      0.89      0.89      1876
#            7       0.85      0.91      0.88      1003
#            8       0.86      0.86      0.86      1739
#            9       0.91      0.94      0.92       416
#
#     accuracy                           0.92     12255
#    macro avg       0.92      0.92      0.92     12255
# weighted avg       0.92      0.92      0.92     12255
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       447
#            1       0.92      0.89      0.91       447
#            2       0.92      0.86      0.89       658
#            3       0.91      0.89      0.90       716
#            4       0.82      0.83      0.82       467
#            5       0.76      0.71      0.73       364
#            6       0.76      0.81      0.78       808
#            7       0.70      0.73      0.72       461
#            8       0.67      0.70      0.69       701
#            9       0.71      0.69      0.70       184
#
#     accuracy                           0.81      5253
#    macro avg       0.81      0.81      0.81      5253
# weighted avg       0.82      0.81      0.82      5253

# %%
print('Light Gradient Boosting Classifier')
## Light Gradient Boosting Classifier
lgb_classifier = lgb.LGBMClassifier()
param_grid = {
    'boosting_type': ['gbdt', 'dart', 'goss'],
    'num_leaves': [15, 31, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'objective': ['multiclass'],  # for multiclass classification
    'random_state': [42],
}

random_search = RandomizedSearchCV(
    estimator=lgb_classifier,
    param_distributions=param_grid,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring=['precision_macro', 'recall_macro', 'f1_macro'],
    cv=5,  # Number of cross-validation folds
    refit='f1_macro',
    verbose=2,
    n_jobs=-1,  # Use all available processors
    random_state=42
)

# Fit the RandomizedSearchCV object to the data
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best Parameters:", random_search.best_params_)
print('Train Report\n', classification_report(y_train, random_search.predict(x_train)))
print('Test Report\n', classification_report(y_test, random_search.predict(x_test)))
# Out:
# Light Gradient Boosting Classifier
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Parameters: {'random_state': 42, 'objective': 'multiclass', 'num_leaves': 31, 'n_estimators': 50, 'learning_rate': 0.2, 'boosting_type': 'dart'}
# Train Report
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1053
#            1       0.90      0.86      0.88      1017
#            2       0.88      0.82      0.85      1538
#            3       0.93      0.90      0.92      1724
#            4       0.87      0.93      0.90      1033
#            5       0.90      0.84      0.87       856
#            6       0.81      0.85      0.83      1876
#            7       0.79      0.87      0.83      1003
#            8       0.81      0.78      0.79      1739
#            9       0.88      0.93      0.90       416
#
#     accuracy                           0.87     12255
#    macro avg       0.87      0.88      0.88     12255
# weighted avg       0.87      0.87      0.87     12255
#
# Test Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       447
#            1       0.81      0.78      0.79       447
#            2       0.82      0.76      0.78       658
#            3       0.89      0.85      0.87       716
#            4       0.81      0.85      0.83       467
#            5       0.79      0.72      0.75       364
#            6       0.74      0.79      0.76       808
#            7       0.69      0.74      0.71       461
#            8       0.67      0.67      0.67       701
#            9       0.70      0.72      0.71       184
#
#     accuracy                           0.79      5253
#    macro avg       0.78      0.78      0.78      5253
# weighted avg       0.79      0.79      0.79      5253

# %% [markdown]
# We have used SMOTE for oversampling.
# SMOTE stands for "Synthetic Minority Over-sampling Technique." It is an advanced technique used to address class imbalance in machine learning datasets. Instead of simply duplicating existing minority class samples, SMOTE generates synthetic samples for the minority class by interpolating between existing samples. It aims to balance the class distribution by creating synthetic examples that are similar to the existing minority class samples but not identical.
# - Reducing Overfitting
# - Improved Generalization
# - Handling Class Imbalance

# %% [markdown]
# - After comparing the performance of Case 1 (Oversampling and Undersampling) and Case 2 (Oversampling Only) after resampling, it appears that Case 2 is generally better as there is no data loss as well as f1 scores are increased.
# - Case 2 tends to achieve better F1-scores, which suggests that it is a more effective approach for addressing the class imbalance issue in this particular dataset.
# - Comparing the F1-Scores, we can see that the XGBoost algorithm performed the best among the tested algorithms.
